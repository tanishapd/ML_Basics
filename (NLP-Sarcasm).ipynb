# %%
import json
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data=pd.read_json("Sarcasm_Headlines_dataset.json",lines=True)

# %%
data.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
data.drop(['article_link'],axis=1)
# Out:
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# ...                                                  ...           ...
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
# [26709 rows x 2 columns]

# %%
sentence=data['headline'].tolist()

# %%
label=data['is_sarcastic'].tolist()

# %%
sentence[:10]
# Out:
# ["former versace store clerk sues over secret 'black code' for minority shoppers",
#  "the 'roseanne' revival catches up to our thorny political mood, for better and worse",
#  "mom starting to fear son's web series closest thing she will have to grandchild",
#  'boehner just wants wife to listen, not come up with alternative debt-reduction ideas',
#  'j.k. rowling wishes snape happy birthday in the most magical way',
#  "advancing the world's women",
#  'the fascinating case for eating lab-grown meat',
#  'this ceo will send your kids to school, if you work for his company',
#  'top snake handler leaves sinking huckabee campaign',
#  "friday's morning email: inside trump's presser for the ages"]

# %%
nltk.download('punkt')
stop_words=set(stopwords.words("english"))

#Function to remove stopwords from a single sentence
def remove_stopwords(sentence):
    words=nltk.word_tokenize(sentence)
    filtered_words=[word for word in words if word.lower()not in stop_words]
    return"".join(filtered_words)

#Remove stopwords from each sentence in the list
sentence=[remove_stopwords(sentence) for sentence in sentence]

#Print the sentences without stopwords
sentence[:10]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ["formerversacestoreclerksuessecret'blackcode'minorityshoppers",
#  "'roseanne'revivalcatchesthornypoliticalmood,betterworse",
#  "momstartingfearson'swebseriesclosestthinggrandchild",
#  'boehnerwantswifelisten,comealternativedebt-reductionideas',
#  'j.k.rowlingwishessnapehappybirthdaymagicalway',
#  "advancingworld'swomen",
#  'fascinatingcaseeatinglab-grownmeat',
#  'ceosendkidsschool,workcompany',
#  'topsnakehandlerleavessinkinghuckabeecampaign',
#  "friday'smorningemail:insidetrump'spresserages"]

# %%
import string

nltk.download('punkt')

# Define a set of punctuation characters
punctuations = set(string.punctuation)

# Function to remove punctuation from a single sentence
def remove_punctuation(sentence):
    words = nltk.word_tokenize(sentence)
    filtered_words = [word for word in words if word.lower() not in punctuations]
    return " ".join(filtered_words)

#Remove punctuations from each sentence in the list
sentence=[remove_punctuation(sentence) for sentence in sentence]

#Print the sentences without punctuations
sentence[:10]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ["formerversacestoreclerksuessecret'blackcode'minorityshoppers",
#  "'roseanne'revivalcatchesthornypoliticalmood betterworse",
#  "momstartingfearson'swebseriesclosestthinggrandchild",
#  'boehnerwantswifelisten comealternativedebt-reductionideas',
#  'j.k.rowlingwishessnapehappybirthdaymagicalway',
#  "advancingworld'swomen",
#  'fascinatingcaseeatinglab-grownmeat',
#  'ceosendkidsschool workcompany',
#  'topsnakehandlerleavessinkinghuckabeecampaign',
#  "friday'smorningemail insidetrump'spresserages"]

# %%
train_size=round(len(sentence)*0.75)
train_sen=sentence[0:train_size]
test_sen=sentence[train_size:]
train_label=label[0:train_size]
test_label=label[train_size:]

# %%
vocab_size=10000
oov_tok="oov"

# %%
tokenizer=Tokenizer(num_words=vocab_size,oov_token=oov_tok)
tokenizer.fit_on_texts(train_sen)
word_index=tokenizer.word_index

# %%
word_index
# Out:
# {'oov': 1,
#  's': 2,
#  'report': 3,
#  'year': 4,
#  'u': 5,
#  "''": 6,
#  'study': 7,
#  "'s": 8,
#  'a': 9,
#  'k': 10,
#  'watch': 11,
#  'c': 12,
#  'to': 13,
#  '000': 14,
#  'video': 15,
#  'historicalarchives': 16,
#  'j': 17,
#  'trump': 18,
#  'breaking': 19,
#  'of': 20,
#  'huffpollster': 21,
#  '5': 22,
#  'poll': 23,
#  'n': 24,
#  'huffpostrise': 25,
#  '11': 26,
#  "n't": 27,
#  '1': 28,
#  'in': 29,
#  '2': 30,
#  'd': 31,
#  'the': 32,
#  'ex': 33,
#  'm': 34,
#  '9': 35,
#  'anti': 36,
#  'yes': 37,
#  'obama': 38,
#  'policesay': 39,
#  '7': 40,
#  't': 41,
#  'update': 42,
#  'self': 43,
#  'on': 44,
#  '20': 45,
#  '10': 46,
#  '3': 47,
#  '2017': 48,
#  'and': 49,
#  'huffposthill': 50,
#  'f': 51,
#  '8': 52,
#  "friday'smorningemail": 53,
#  'look': 54,
#  'old': 55,
#  'police': 56,
#  'sundayroundup': 57,
#  "thursday'smorningemail": 58,
#  '4': 59,
#  'watchlive': 60,
#  'real': 61,
#  'middle': 62,
#  'non': 63,
#  '20funniesttweetswomenweek': 64,
#  'i': 65,
#  '6': 66,
#  'first': 67,
#  'for': 68,
#  'all': 69,
#  'time': 70,
#  'out': 71,
#  'e': 72,
#  'l': 73,
#  'by': 74,
#  'well': 75,
#  'sen': 76,
#  'foot': 77,
#  'womenbusinessq': 78,
#  'nsfw': 79,
#  'g': 80,
#  'w': 81,
#  "wednesday'smorningemail": 82,
#  '25': 83,
#  "tuesday'smorningemail": 84,
#  'right': 85,
#  'part1': 86,
#  'part2': 87,
#  'o': 88,
#  'up': 89,
#  '12': 90,
#  'lin': 91,
#  'surprise': 92,
#  'second': 93,
#  '100': 94,
#  'al': 95,
#  'hillaryclinton': 96,
#  'fridaytalkingpoints': 97,
#  'donaldtrump': 98,
#  'dr': 99,
#  '50': 100,
#  'dailymeditation': 101,
#  'com': 102,
#  'actually': 103,
#  'america': 104,
#  'long': 105,
#  'un': 106,
#  'month': 107,
#  '45': 108,
#  'whitehouse': 109,
#  '90': 110,
#  'science': 111,
#  'one': 112,
#  'off': 113,
#  '15': 114,
#  "monday'smorningemail": 115,
#  'mr': 116,
#  "'nowayprevent": 117,
#  "'saysnationregularlyhappens": 118,
#  'go': 119,
#  'audio': 120,
#  'jay': 121,
#  'high': 122,
#  'r': 123,
#  'women': 124,
#  '14': 125,
#  'st': 126,
#  'president': 127,
#  'thank': 128,
#  'trevornoah': 129,
#  'really': 130,
#  '87': 131,
#  'dark': 132,
#  '96': 133,
#  'tedcruz': 134,
#  'pre': 135,
#  'photos': 136,
#  'kimjong': 137,
#  'fourth': 138,
#  'reports': 139,
#  'money': 140,
#  'sources': 141,
#  'laid': 142,
#  'olds': 143,
#  'oh': 144,
#  'cops': 145,
#  'post': 146,
#  '60': 147,
#  'two': 148,
#  'officialsays': 149,
#  'before': 150,
#  'order': 151,
#  'bush': 152,
#  'art': 153,
#  'gradelevel': 154,
#  'shit': 155,
#  '30': 156,
#  'half': 157,
#  'law': 158,
#  '18': 159,
#  '98': 160,
#  'rep': 161,
#  'family': 162,
#  'military': 163,
#  'gov': 164,
#  'deep': 165,
#  'x': 166,
#  'at': 167,
#  '2014': 168,
#  'esteem': 169,
#  'fuck': 170,
#  'know': 171,
#  'sold': 172,
#  'think': 173,
#  "patrick'sday": 174,
#  'much': 175,
#  'friends': 176,
#  'presidentobama': 177,
#  'officials': 178,
#  'eco': 179,
#  'exclusive': 180,
#  'louisc': 181,
#  'yet': 182,
#  'sure': 183,
#  'firstnighter': 184,
#  'dept': 185,
#  'live': 186,
#  '40': 187,
#  'studysays': 188,
#  'lasvegasreview': 189,
#  'syria': 190,
#  'so': 191,
#  'home': 192,
#  'white': 193,
#  'sexmarriage': 194,
#  'like': 195,
#  'same': 196,
#  '89': 197,
#  'drug': 198,
#  'sort': 199,
#  'basharal': 200,
#  'fast': 201,
#  'write': 202,
#  'fed': 203,
#  'baby': 204,
#  'health': 205,
#  'no': 206,
#  'face': 207,
#  'leather': 208,
#  'mail': 209,
#  'blood': 210,
#  'history': 211,
#  'dolist': 212,
#  'shirts': 213,
#  'hope': 214,
#  "trump'samerica": 215,
#  '200': 216,
#  'parents': 217,
#  'stressed': 218,
#  '80': 219,
#  'tacobell': 220,
#  'fbi': 221,
#  'israel': 222,
#  '83': 223,
#  'founder': 224,
#  'last': 225,
#  'good': 226,
#  'bleary': 227,
#  'hey': 228,
#  'alcohol': 229,
#  'parttwo': 230,
#  'wade': 231,
#  'great': 232,
#  'depression': 233,
#  'stagedoor': 234,
#  '35': 235,
#  'cash': 236,
#  'soleremaininglungfilledrich': 237,
#  'satisfyingflavor': 238,
#  'musicals': 239,
#  'got': 240,
#  'friendly': 241,
#  'says': 242,
#  'with': 243,
#  '84': 244,
#  'part': 245,
#  '“': 246,
#  '”': 247,
#  'people': 248,
#  'elizabethwarren': 249,
#  'men': 250,
#  'lightsgo': 251,
#  'gun': 252,
#  'b': 253,
#  'jordan': 254,
#  'review': 255,
#  'michelleobama': 256,
#  'grateful': 257,
#  '17': 258,
#  'reportfinds': 259,
#  'once': 260,
#  'aids': 261,
#  'plus': 262,
#  '32': 263,
#  'georgew': 264,
#  'green': 265,
#  '43': 266,
#  'guys': 267,
#  'ivanka': 268,
#  'tarajip': 269,
#  'chrischristie': 270,
#  'run': 271,
#  'hint': 272,
#  'life': 273,
#  'funniesttweetsparentsweek': 274,
#  'black': 275,
#  'isis': 276,
#  'cookingcuff': 277,
#  'states': 278,
#  'meatlessmonday': 279,
#  'funniesttweetswomenweek': 280,
#  '92': 281,
#  '23': 282,
#  'donaldtrumpjr': 283,
#  '34': 284,
#  'eat': 285,
#  'behold': 286,
#  'double': 287,
#  'q': 288,
#  'laborday': 289,
#  'wal': 290,
#  'theater': 291,
#  'hip': 292,
#  "'d": 293,
#  'clinton': 294,
#  'man': 295,
#  'bill': 296,
#  'late': 297,
#  'romney': 298,
#  'nazis': 299,
#  'side': 300,
#  'help': 301,
#  'living': 302,
#  'early': 303,
#  'talk': 304,
#  'gluten': 305,
#  'pollshows': 306,
#  'or': 307,
#  'sweating': 308,
#  'earthday': 309,
#  'ugh': 310,
#  '22': 311,
#  '15minimumwage': 312,
#  'listen': 313,
#  "peter'sbasilica": 314,
#  'you': 315,
#  'meat': 316,
#  'refugees': 317,
#  'fda': 318,
#  'week': 319,
#  'johnoliver': 320,
#  'new': 321,
#  'inside': 322,
#  'co': 323,
#  '5million': 324,
#  'allies': 325,
#  '1dead': 326,
#  "internationalwomen'sday": 327,
#  'magic': 328,
#  'markeredinitialsfaildeterbreakroomrice': 329,
#  'cakethief': 330,
#  'cry': 331,
#  'holyshit': 332,
#  'modern': 333,
#  'copssay': 334,
#  "'sname": 335,
#  'never': 336,
#  'wrong': 337,
#  'congressapproves': 338,
#  'newbook': 339,
#  'power': 340,
#  'criticism': 341,
#  'girlfriend': 342,
#  'gopsen': 343,
#  'whoops': 344,
#  'antarcticobservationalcomicrunningideas': 345,
#  'after': 346,
#  'war': 347,
#  'torn': 348,
#  'lawsuitsays': 349,
#  'eleven': 350,
#  'bad': 351,
#  '600': 352,
#  'way': 353,
#  'snl': 354,
#  'bestchancedefeatroymooremaydemocraticpartylielow': 355,
#  'quick': 356,
#  "'ll": 357,
#  'activists': 358,
#  'dead65': 359,
#  "losercan'tevengetwifepregnant": 360,
#  'jillabramson': 361,
#  'night': 362,
#  'areamankilledcommittee': 363,
#  'follow': 364,
#  'stormydaniels': 365,
#  'win': 366,
#  'cuba': 367,
#  'lawyersays': 368,
#  'crisis': 369,
#  'weekend': 370,
#  '160': 371,
#  'talktome': 372,
#  'career': 373,
#  'drink': 374,
#  'shirt': 375,
#  'jetblueoffering': 376,
#  'dayflashsale': 377,
#  'mondaymatters': 378,
#  'schoolseason': 379,
#  'areamanreports': 380,
#  '70': 381,
#  'newu': 382,
#  'timehigh': 383,
#  'kind': 384,
#  'climatechange': 385,
#  '44': 386,
#  'interview': 387,
#  'lastingmarriage': 388,
#  'peace': 389,
#  'kerrywashington': 390,
#  'hourworkday': 391,
#  'joanmoran': 392,
#  'arab': 393,
#  'admit': 394,
#  'visit': 395,
#  'podcastreview': 396,
#  'jebbush': 397,
#  'pure': 398,
#  'lago': 399,
#  'love': 400,
#  'ultra': 401,
#  'nakedtruth': 402,
#  'four': 403,
#  "y'allurgedgofuckyo'selves": 404,
#  'twonon': 405,
#  '130': 406,
#  'eatingcontest': 407,
#  'populace': 408,
#  'part4': 409,
#  'eastst': 410,
#  'absolutelylasttimebouncercleansvomit': 411,
#  'must': 412,
#  'icymi': 413,
#  'numbers': 414,
#  'shame': 415,
#  'future': 416,
#  'business': 417,
#  'ownedbusinesses': 418,
#  'anger': 419,
#  '36': 420,
#  "'scatch": 421,
#  'libya': 422,
#  'freddieprinzejr': 423,
#  'zambonicrimefamilyindictedice': 424,
#  'shavingscandal': 425,
#  'bushlovelychileanambassador': 426,
#  "'mustpaint": 427,
#  'hate': 428,
#  'surf': 429,
#  'internet': 430,
#  'can': 431,
#  'la': 432,
#  'sadly': 433,
#  '13': 434,
#  'whitepeople': 435,
#  'mrs': 436,
#  'smith': 437,
#  'manthinksreceptionisthitting': 438,
#  '16': 439,
#  'marylandgov': 440,
#  'bathroom': 441,
#  'compulsivedisorder': 442,
#  'problem': 443,
#  'gaunt': 444,
#  'need': 445,
#  'stressedwork': 446,
#  'birdbigplanscage': 447,
#  'mccain': 448,
#  'cross': 449,
#  'comic': 450,
#  'election': 451,
#  'get': 452,
#  'related': 453,
#  'far': 454,
#  'jr': 455,
#  'yeah': 456,
#  'excerpt': 457,
#  'nationdemandsslow': 458,
#  "o'": 459,
#  'compulsivedisorderobsessive': 460,
#  'hands': 461,
#  'dearwhitepeople': 462,
#  "saturday'smorningemail": 463,
#  'funniesedition': 464,
#  'inner': 465,
#  'sauce': 466,
#  'fisher': 467,
#  'georgia': 468,
#  'donut': 469,
#  'divorce': 470,
#  'nationalfilmstripboardcallsquiet': 471,
#  'sci': 472,
#  'microwave': 473,
#  'alone': 474,
#  'your': 475,
#  'next': 476,
#  'gopcongressman': 477,
#  'bestabudhabi': 478,
#  "'well": 479,
#  'seventh': 480,
#  'tpp': 481,
#  'revisited': 482,
#  'cnn': 483,
#  'markcutler': 484,
#  'breathe': 485,
#  'single': 486,
#  'oscar': 487,
#  'forgotten': 488,
#  'willowrented': 489,
#  'cost': 490,
#  'afro': 491,
#  'teary': 492,
#  'tyler': 493,
#  'mitresearchersdiscover': 494,
#  'hour': 495,
#  'quiz': 496,
#  "'re": 497,
#  'personalphilosophystolenmartinlutherkingjr': 498,
#  'best': 499,
#  'class2014': 500,
#  'guitar': 501,
#  'democrats': 502,
#  'sad': 503,
#  'vaticanunveilsnewpopesignal': 504,
#  'huffpostrisemorningnewsbrief': 505,
#  'book': 506,
#  'media': 507,
#  '65': 508,
#  'jan': 509,
#  "'look": 510,
#  'islamicfundamentalistscondemncasualday': 511,
#  '0': 512,
#  'pro': 513,
#  'uh': 514,
#  'warning': 515,
#  'applewatch': 516,
#  'firsttime': 517,
#  'close': 518,
#  'magicalgallerytransformsdullobjectsart': 519,
#  'dance': 520,
#  'truthfiction': 521,
#  'spider': 522,
#  '10easy': 523,
#  'god': 524,
#  'knows': 525,
#  'housecards': 526,
#  'oneyearlater': 527,
#  "shapemagazinedeclaresjuly'letgo'month": 528,
#  '¯': 529,
#  'full': 530,
#  'areamanlikesfood': 531,
#  'read': 532,
#  'eating': 533,
#  'girl': 534,
#  'seanhannity': 535,
#  'foxnewshost': 536,
#  'surveyfinds': 537,
#  '500': 538,
#  'markzuckerberg': 539,
#  'waiting': 540,
#  'florida': 541,
#  'systemsadministratorwouldfucknewtrainee': 542,
#  'ray': 543,
#  'chief': 544,
#  'johnson': 545,
#  'say': 546,
#  'mom': 547,
#  '63': 548,
#  "'americanhorrorstory": 549,
#  'mixed': 550,
#  "hmotargetsblacks'rappinggood'healthcampaign": 551,
#  'jesus': 552,
#  "book'retalking": 553,
#  '49': 554,
#  'impossible': 555,
#  'grief': 556,
#  'bye': 557,
#  'better': 558,
#  'tired': 559,
#  'cast': 560,
#  'virginia': 561,
#  'springbreak2016': 562,
#  'breakingbadlooneyfront': 563,
#  'syrianrebels': 564,
#  'zip': 565,
#  'fruitislamcausemansoilfruitlooms': 566,
#  'die': 567,
#  '5thingseveryonegetswrongnapping': 568,
#  'mega': 569,
#  'kids': 570,
#  'mindfulness20s': 571,
#  '30daysonlinedating': 572,
#  'neighborsrememberserialkillerserialkiller': 573,
#  'metoomovement': 574,
#  'public': 575,
#  'circusrunawaylookingforwardhometownshow': 576,
#  'martinlutherkingjr': 577,
#  'yoga': 578,
#  'departmentinteriorsetsaside50': 579,
#  'father': 580,
#  'texas': 581,
#  'roadtripplaylist': 582,
#  'bring': 583,
#  'nepalcalls': 584,
#  'newone': 585,
#  'weekabortionban': 586,
#  'educatingdemocracy': 587,
#  'cheese': 588,
#  'rev': 589,
#  'jessicasimpsonrevealsslimmerfigurechoppinglimbs': 590,
#  'yemen': 591,
#  'frito': 592,
#  'nasa': 593,
#  '000feet': 594,
#  'square': 595,
#  "france'sfar": 596,
#  'pope': 597,
#  'christmas': 598,
#  '21': 599,
#  "twodead'kindbrutal'slaying": 600,
#  'fun': 601,
#  'sexcouples': 602,
#  'twice': 603,
#  '55': 604,
#  'americandream': 605,
#  'sundaymealprep': 606,
#  'tough': 607,
#  'happiness': 608,
#  'womenbusiness': 609,
#  'lying': 610,
#  'faith': 611,
#  'loaded': 612,
#  'fil': 613,
#  'important': 614,
#  'sportsocietyarete': 615,
#  'gross': 616,
#  'buildingexercise': 617,
#  'gaygeneisolated': 618,
#  'ostracized': 619,
#  'melgibson': 620,
#  'losesu': 621,
#  'sanders': 622,
#  'seven': 623,
#  'facebook': 624,
#  'getsleep': 625,
#  'semitism': 626,
#  'third': 627,
#  'netanyahu': 628,
#  'eye': 629,
#  '99': 630,
#  'joebiden': 631,
#  'italy': 632,
#  'tombrady': 633,
#  'podiatristjerk': 634,
#  '2billion': 635,
#  'world': 636,
#  'wow': 637,
#  'madmen': 638,
#  'partii': 639,
#  'weird': 640,
#  'bath': 641,
#  'issues': 642,
#  'said': 643,
#  'yup': 644,
#  'ca': 645,
#  'lonemansix': 646,
#  "pack'partying": 647,
#  'celebritydisappointedmeetingfan': 648,
#  'doubt': 649,
#  'weekendroundup': 650,
#  '79': 651,
#  '42': 652,
#  'fastest': 653,
#  'responsible': 654,
#  'ever': 655,
#  '26': 656,
#  'georgeh': 657,
#  'fyi': 658,
#  'game': 659,
#  'vergaraera': 660,
#  'accordingpinterest': 661,
#  'funniestparentingtweets': 662,
#  'momsdadssaidtwitterweek': 663,
#  'data': 664,
#  'p': 665,
#  'lgbtlaw': 666,
#  'obesity': 667,
#  'courtrules': 668,
#  'day': 669,
#  'emails': 670,
#  'alabama': 671,
#  'ukraine': 672,
#  'fivedays': 673,
#  'defense': 674,
#  'herofirefighter': 675,
#  'mhero': 676,
#  'sing': 677,
#  'fool': 678,
#  'eighth': 679,
#  'nursing': 680,
#  "guywipedimmediatelyclaims'sfine": 681,
#  'area5': 682,
#  'oldtelling': 683,
#  "'scomplicated": 684,
#  'huffpostheadlinequiz': 685,
#  'janiceregisterthree': 686,
#  'conversation': 687,
#  'christ': 688,
#  '29': 689,
#  '20bill': 690,
#  '88': 691,
#  'sometimes': 692,
#  'bonebroth': 693,
#  'presidenttrump': 694,
#  'americans': 695,
#  'play': 696,
#  'senator': 697,
#  'atlanta': 698,
#  'explained': 699,
#  'ireland': 700,
#  'johnboehner': 701,
#  'kanyewest': 702,
#  'death': 703,
#  'researchers': 704,
#  '85': 705,
#  'small': 706,
#  'million': 707,
#  "exxonmobilswears'sgoingstarttaxesearlyyear": 708,
#  '400': 709,
#  'waaah': 710,
#  'housekeeperbusysassy': 711,
#  'qaeda': 712,
#  'marcoses': 713,
#  'joke': 714,
#  'firstu': 715,
#  'hearted': 716,
#  'binge': 717,
#  'louis': 718,
#  'guyglasseseveryrockshow': 719,
#  'extra': 720,
#  'dead86': 721,
#  'jimmyfallon': 722,
#  'civilrightsactivist': 723,
#  'stories': 724,
#  'free': 725,
#  'drive': 726,
#  'republicans': 727,
#  'brazil': 728,
#  'rotatingknifevortexclosedpendingsafetyinvestigation': 729,
#  'newyork': 730,
#  "formerversacestoreclerksuessecret'blackcode'minorityshoppers": 731,
#  "'roseanne'revivalcatchesthornypoliticalmood": 732,
#  'betterworse': 733,
#  "momstartingfearson'swebseriesclosestthinggrandchild": 734,
#  'boehnerwantswifelisten': 735,
#  'comealternativedebt': 736,
#  'reductionideas': 737,
#  'rowlingwishessnapehappybirthdaymagicalway': 738,
#  "advancingworld'swomen": 739,
#  'fascinatingcaseeatinglab': 740,
#  'grownmeat': 741,
#  'ceosendkidsschool': 742,
#  'workcompany': 743,
#  'topsnakehandlerleavessinkinghuckabeecampaign': 744,
#  "insidetrump'spresserages": 745,
#  'airlinepassengerstacklemanrushescockpitbombthreat': 746,
#  'facebookreportedlyworkinghealthcarefeaturesapps': 747,
#  "northkoreapraisestrumpurgesusvotersreject'dullhillary": 748,
#  "cnn'sjeffreylord'indefensible": 749,
#  'barcelonaholdshugeprotestsupportrefugees': 750,
#  "nuclearbombdetonatesrehearsal'spider": 751,
#  "man'musical": 752,
#  "cosbylawyerasksaccusersn'tcomeforwardsmearedlegalteamyearsago": 753,
#  'stockanalystsconfused': 754,
#  'frightenedboarmarket': 755,
#  "bloomberg'sprogrambuildbettercitiesgotbigger": 756,
#  'craighicksindicted': 757,
#  'courtroomsketchartistclearmangainfluences': 758,
#  'trumpassuresnationdecisionsyrianairstrikescamecarefullyconsideringpassingwhims': 759,
#  'qatardeportingdutchwomanreporteddruggedraped': 760,
#  "n'tgocircus": 761,
#  'tedcruzhitspanicbutton': 762,
#  "'wecouldlosehousescongress": 763,
#  'writersmustplansurprised': 764,
#  'obamavisitsarlingtonnationalcemeteryhonorveterans': 765,
#  'conbackbehindbar': 766,
#  'carefulconsideration': 767,
#  'bushrecommendsoildrilling': 768,
#  'remembrancebeginningtask': 769,
#  'islamistmotivekillingnemtsovnonsense': 770,
#  "gillianjacobs'slikekissadambrody": 771,
#  "ubervowsrepaynycdrivers'tensmillions'taxsnafu": 772,
#  'applemaypoachedelectricmotorcyclecompanydeath': 773,
#  'resistantbacteriaoftenlurkchildren': 774,
#  "dogs'sandboxes": 775,
#  'seemuslimairport': 776,
#  'giantaltoidheadingtowardearth': 777,
#  "'moana'sailsstraighttopboxofficemassive": 778,
#  '81': 779,
#  '1millionopening': 780,
#  'seligcountedmoneybaseballlostnextgenerationfans': 781,
#  'robinwilliamsinflictedholidaymoviegoerseighthstraightyear': 782,
#  "devinnunesvows'never'revealsourcesurveillanceclaims": 783,
#  'scottusedstopbreathingnearly40timeshour': 784,
#  'devicechangedlife': 785,
#  'rescuersheroicallyhelpbeachedgarbagebackocean': 786,
#  'medicsdropsoccerplayerstretcher': 787,
#  "'sticked": 788,
#  'givegiftplayholidayseason': 789,
#  'christianbalevisitssikhtemplevictims': 790,
#  'spicerdeniesendingmaternitycareguaranteewouldmeanwomenpayhealthcare': 791,
#  "'rightlivelifecomplete": 792,
#  'stunnedhorror': 793,
#  "'addedconstitution": 794,
#  'nasaalmostpositivemarsrocky': 795,
#  'monsterundeterrednight': 796,
#  'light': 797,
#  'diy': 798,
#  'sportsequipmentcloset': 799,
#  '3injuredshootingt': 800,
#  'concertnyc': 801,
#  "longtimeteacherretireswithoutchangingsinglestudent'slife": 802,
#  'donaldtrumpheadingserieswinsnortheast': 803,
#  'pollssay': 804,
#  "donaldtrumpwouldn'treadycashself": 805,
#  'financeentirecampaign—analysis': 806,
#  "new'starwars'filmdisappointsdie": 807,
#  'hardniennunbfans': 808,
#  "batsshooednation'swaterslidetunnelspreparationsummer": 809,
#  'mobilenewscrewreportsvanbreaking': 810,
#  "unrightschiefcallshumanitariansituationsyria'anoutrage": 811,
#  "tracksantaclaus'flightaroundworldchristmaseve": 812,
#  'obamacoloradoappraised': 813,
#  "troubletv'safrica": 814,
#  'britaunveilsnewin': 815,
#  'throatwaterfilters': 816,
#  'johngrishamslowlysurelyclimbinglistgreatestlivingamericanauthors': 817,
#  "ghostcan'tmakesimplecupcoffeewithouteveryonefreaking": 818,
#  'tupperwarenevertrulyrecoverredcurryleftovers': 819,
#  "oneplanet'spowerfulforceschange": 820,
#  'adolescentgirl': 821,
#  'draymondgreentakegamenextlevel': 822,
#  'tuningwnba': 823,
#  "areawomansaid'sorry'118timesyesterday": 824,
#  'ryanlochteapologizesbehaviorrio': 825,
#  'northdakotaheard48hours': 826,
#  '4lessonsprisontaughtpowercontrol': 827,
#  'sickfuckslinegapedeadbody': 828,
#  "america'sfirstmuslimfraternityreallylike": 829,
#  'viciousknotsyria': 830,
#  'untanglingprocesscontainssolutionstime': 831,
#  'congressmanthinksfixeconomydrinkingbeer': 832,
#  'breastimplantsfoundcauseproblemslaboratorymice': 833,
#  'trumpordersstrikessyriaretaliationchemicalattack': 834,
#  "ceo'sfuneralnetworkingdream": 835,
#  'roundschooling': 836,
#  'wouldhelpminoritystudents': 837,
#  '90zenteacherspledgechangeculturefostersabuse': 838,
#  'nypdweighsallowingchokeholdsfollowingericgarnerdeath': 839,
#  'sonnybonofoundationpreventsat': 840,
#  'riskyouthsskiingtrees': 841,
#  "popefrancisremindsworldcaringeartheveryone'sresponsibility": 842,
#  'oldcriestoldmtmproductionskittendead': 843,
#  "boyfriendthought'dcheckthrowentireday": 844,
#  "doctorsrestorekenburns'full": 845,
#  "colorvisionremovingmassivetumorfilmmaker'svisualcortex": 846,
#  "'gravity": 847,
#  "'12yearsslave'tie2014pgaawards": 848,
#  'nationalcomingday': 849,
#  '150lgbtqsportspeoplecomelastyear': 850,
#  'johnoliverlaysdisturbingwaystrumpimpactsamerica': 851,
#  'housegopcrackdowncontinues': 852,
#  "'mustmakesureskillspleasegrandson": 853,
#  "'saysqueenelizabethdisrobingmeghanmarkle": 854,
#  'manvisitinghometownamazedfindchildhoodinsecuritiesstill': 855,
#  'worldcupstarattackedgiantbug': 856,
#  'clintonbecomesfirstpresidentclear18feetpolevault': 857,
#  'hunters': 858,
#  'thompsonshootsmouthonelasttime': 859,
#  "inhofe'sgrandclimateconspiracytheory": 860,
#  "'sbarbrastreisand": 861,
#  '5questionswishyoungerpeoplewouldstopasking': 862,
#  'albuquerqueshooterloose': 863,
#  'gunmanleaves1dead': 864,
#  '3injured': 865,
#  "'slikeloseeverythingflood": 866,
#  "demilovatodropsemotional'nightingale'musicvid": 867,
#  'mileycyrusliamhemsworthsmoochnye': 868,
#  'worldnotices': 869,
#  'jealousgpsclearlywantsmanbackwife': 870,
#  "'parksrec'starnataliemoralescomesqueer": 871,
#  'topitalytours2015': 872,
#  'kaiagerber': 873,
#  "cindycrawford'sdaughter": 874,
#  'landsmajorfashioncampaign': 875,
#  'grantsclippers': 876,
#  '12newnets': 877,
#  'jamescordenroastsdavidbeckhammatchingoutfitsposh': 878,
#  'caféaddsheartbreakinglittlelunchmenu': 879,
#  "mcdonald'ssayspackaging100percentgreen2025": 880,
#  "krisjennerturnedwaydrunkenvalentine'sdaykaraoke": 881,
#  'whaleregretseating290': 882,
#  '000plasticpokerchipsfellcontainership': 883,
#  "texasebolapatient'fightinglife": 884,
#  "'islateaudition": 885,
#  "'asksperfectactorrole": 886,
#  'pokingheadroomproducersgivinghope': 887,
#  'robertdeniroturn58movierole': 888,
#  'scottpruitt': 889,
#  'answerswhethertrumpbelievesclimatechange': 890,
#  'accusedfathersonurinalthievesflushedcops': 891,
#  "'justtakeslow": 892,
#  "'llfine": 893,
#  "'drunkdriverassuresselfspeedingawaystolenpolicecar": 894,
#  '3libertariansfuel': 895,
#  "7millionsuperpacphiladelphia'smayoraldemocraticprimary": 896,
#  "airforcelongerrequire'sohelpgod'enlistmentoaths": 897,
#  'paulnewmandiesconsuming51hard': 898,
#  'boiledeggs': 899,
#  'yakchewsthoughtfully': 900,
#  "manworrieddrugdealer'spickingphone": 901,
#  "dadrecommendshotel10milesawaycity'revisiting": 902,
#  'explosionfellsbuildingoutsideparis': 903,
#  'killingleast2': 904,
#  "sourcedonaldtrump'smilitaryexpertisefinallyrevealed": 905,
#  'unionclaimssanderscampaignstaffersposedmembersinfluenceworkers': 906,
#  "seattlemayor'saccusersex": 907,
#  'abuselawsuitcomesforward': 908,
#  'southerncomfortcomfortssoutherner': 909,
#  'swedishpolicefeaturedfilmshownfoxnewssayselectivelyedited': 910,
#  'chromatfeatures1': 911,
#  '2plus': 912,
#  'sizemodelsrunway': 913,
#  'councilmancallsbaltimorerappersinspirestudents': 914,
#  '10qualitiesinnerspirit': 915,
#  'chubbyjewishboydreamsonedaynextapatowmuse': 916,
#  "parentingadvice'ddaregive": 917,
#  'familychoosesdifferentdogreincarnatedgrandfather': 918,
#  'celebritiescelebratefourthjulyfunsun': 919,
#  'westernwomensaveworld': 920,
#  'michellephan': 921,
#  "youtube's'beautybestie": 922,
#  "'empowerswomenoutside": 923,
#  "caitlynjennerrespondsrickygervais'goldenglobesjokes": 924,
#  'joybeharrespondsmichaelflynnguiltypleapurejoy': 925,
#  '6thingsonetellswomenweightlossjourney': 926,
#  'fandisappointedlearnl': 927,
#  'ronhubbardscientologist': 928,
#  'marriagebreaksprocreativedifferences': 929,
#  'ne': 930,
#  'yohelpsraise': 931,
#  '3millioncaliforniaengineeringschool': 932,
#  "elizabethwarrencallsdonaldtrump'racistbully": 933,
#  'sixdead': 934,
#  '10hurtbaltimorecommuter': 935,
#  'schoolbuscrash': 936,
#  'foxnewsproblemsolverswayheads': 937,
#  'kimgordonclarifiescommentslanadelreyfeminism': 938,
#  "assadtriestinybitsaringasselfsee'slike": 939,
#  "niececancer'mticked": 940,
#  'supermodelstephanieseymourarrested': 941,
#  'chargeddrunkendriving': 942,
#  'scoliosis': 943,
#  'needknow': 944,
#  "controversyeruptsukretailerremovesgenderlabelskids'clothes": 945,
#  'teacherbitchespaychecksixth': 946,
#  'gradeclass': 947,
#  'areainsurancesalesmancelebrates14thyearquotingfletch': 948,
#  'friendsalwaysbestbehavioraroundneillabute': 949,
#  'manvowsneverwatchanothersci': 950,
#  'fimoviephysicistfriend': 951,
#  "biologistsannounce'redonerodents": 952,
#  'megynkellydonaldtrump': 953,
#  "'donelevelbestmakestory": 954,
#  'secretbehindonedayprojectgoingviral': 955,
#  'creatingleveragenoneseemsexist': 956,
#  "newmovietapsnation'sloverappingkangaroos": 957,
#  'newspaperstartingworryspendingmuchtimefacebookhealthy': 958,
#  'lawsuitblacklivesmattercentralmeaningfirstamendment': 959,
#  "vaticanputtingfeelerspublicwouldreactanotherchildren'scrusade": 960,
#  "'thewire'castreunitedbaltimoreupliftcommunity": 961,
#  "obama'ssupremecourtnomineebraggedsendingmanprison": 962,
#  "'sfree": 963,
#  'deathd': 964,
#  'mansecurityguardcustodyruledhomicide': 965,
#  'boehnervowsleavesuccessorcleanslate': 966,
#  'trumpmakeslast': 967,
#  'minutepushappealwhites': 968,
#  'facingrisingseas': 969,
#  'remotealaskanvillagevotesmove': 970,
#  "child'sfondestmemoriestimesdadtryingmakethings": 971,
#  'worstplaceworldchild': 972,
#  "momsentencedencouragingboyfriend'ssexassaultbaby": 973,
#  "donaldtrump'sassaultvalues": 974,
#  "women'smarchinspiredrun": 975,
#  "'reunseatinggopmen": 976,
#  'worth': 977,
#  "gopsenatorsn'treadyaccepttrumpchampion": 978,
#  'price': 979,
#  'gougingpharmaceotakescancercompany': 980,
#  'manfailingheedharshlessonspastorderssonicbaconcheeseburgertoaster': 981,
#  "kenburnscompletesdocumentaryfuckingliarsclaimedwatchedentire'jazz'series": 982,
#  "'straightouttacompton'stunningsurprise": 983,
#  'carlyraejepsenreleasednewsingle': 984,
#  "'all": 985,
#  "godhumbledanswer'jeopardy": 986,
#  "'clue": 987,
#  "femalebaristagettinglotbetteravoidingtouchingmalepatrons'handspay": 988,
#  'gunmankillsone': 989,
#  'woundsfourshootinggermannightclub': 990,
#  "couplepoint'recomfortableusingtoilettime": 991,
#  'mountainliontrackedscientistsfounddeadnearmaliburoad': 992,
#  'noahcyrusmakeslate': 993,
#  "nightdebutbelting'make": 994,
#  'scaliagoesabortionbenderpassedchiefjustice': 995,
#  "campbell'sunveilsonebigcan": 996,
#  'sizednoodle': 997,
#  'areamangoingfinishfries': 998,
#  "taylorswiftused'gremlinvoice'writing'1989": 999,
#  "restaurant'seatingchallengerewardspatronconsumereasonablyportionedmeal": 1000,
#  ...}

# %% [markdown]
# # Padding

# %%
max_length=100 #max length of a sentence can be 100,if not specified,
#then the length of the longest sentence is sent 
trunc_type='post'
padding_type='post'

# %%
training_sequences=tokenizer.texts_to_sequences(train_sen)
#assigning sequences,numbers to tokens as model can only train on numbers
training_padded=pad_sequences(training_sequences,maxlen=max_length,padding=padding_type,truncating=trunc_type)
#in any raw text data,naturally there will be sentences of different lengths,all nn require the same input
testing_sequences=tokenizer.texts_to_sequences(test_sen)

testing_padded=pad_sequences(testing_sequences,maxlen=max_length,padding=padding_type,truncating=trunc_type)

# %%
embedding_dim=16
model=tf.keras.Sequential([tf.keras.layers.Embedding(vocab_size,embedding_dim,input_length=max_length),

    tf.keras.layers.GlobalAveragePooling1D(),

    tf.keras.layers.Dense(24,activation='relu'),

    tf.keras.layers.Dense(1,activation='sigmoid')])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 160433 (626.69 KB)
# Trainable params: 160433 (626.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
training_padded=np.array(training_padded)
training_labels=np.array(train_label)
testing_padded=np.array(testing_padded)
testing_labels=np.array(test_label)
#converting the list to array for tensorflow

# %%
#training the model ... finally ghar ja sakte hai

num_epochs=30
history=model.fit(training_padded,training_labels,epochs=num_epochs,validation_data=(testing_padded,testing_labels),verbose=2)
# Out:
# Epoch 1/30
# 626/626 - 3s - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6856 - val_accuracy: 0.5636 - 3s/epoch - 4ms/step
# Epoch 2/30
# 626/626 - 2s - loss: 0.6858 - accuracy: 0.5602 - val_loss: 0.6847 - val_accuracy: 0.5636 - 2s/epoch - 3ms/step
# Epoch 3/30
# 626/626 - 2s - loss: 0.6852 - accuracy: 0.5602 - val_loss: 0.6844 - val_accuracy: 0.5636 - 2s/epoch - 4ms/step
# Epoch 4/30
# 626/626 - 2s - loss: 0.6836 - accuracy: 0.5602 - val_loss: 0.6840 - val_accuracy: 0.5636 - 2s/epoch - 3ms/step
# Epoch 5/30
# 626/626 - 2s - loss: 0.6801 - accuracy: 0.5677 - val_loss: 0.6795 - val_accuracy: 0.5780 - 2s/epoch - 3ms/step
# Epoch 6/30
# 626/626 - 2s - loss: 0.6709 - accuracy: 0.5986 - val_loss: 0.6765 - val_accuracy: 0.5809 - 2s/epoch - 3ms/step
# Epoch 7/30
# 626/626 - 2s - loss: 0.6536 - accuracy: 0.6450 - val_loss: 0.6776 - val_accuracy: 0.5832 - 2s/epoch - 3ms/step
# Epoch 8/30
# 626/626 - 2s - loss: 0.6301 - accuracy: 0.6783 - val_loss: 0.6676 - val_accuracy: 0.5880 - 2s/epoch - 3ms/step
# Epoch 9/30
# 626/626 - 2s - loss: 0.6012 - accuracy: 0.7008 - val_loss: 0.6598 - val_accuracy: 0.5946 - 2s/epoch - 3ms/step
# Epoch 10/30
# 626/626 - 2s - loss: 0.5699 - accuracy: 0.7249 - val_loss: 0.6584 - val_accuracy: 0.5946 - 2s/epoch - 3ms/step
# Epoch 11/30
# 626/626 - 3s - loss: 0.5441 - accuracy: 0.7241 - val_loss: 0.6598 - val_accuracy: 0.5949 - 3s/epoch - 4ms/step
# Epoch 12/30
# 626/626 - 2s - loss: 0.5182 - accuracy: 0.7309 - val_loss: 0.6634 - val_accuracy: 0.5949 - 2s/epoch - 4ms/step
# Epoch 13/30
# 626/626 - 2s - loss: 0.5010 - accuracy: 0.7251 - val_loss: 0.6607 - val_accuracy: 0.5949 - 2s/epoch - 4ms/step
# Epoch 14/30
# 626/626 - 2s - loss: 0.4825 - accuracy: 0.7327 - val_loss: 0.6612 - val_accuracy: 0.5947 - 2s/epoch - 3ms/step
# Epoch 15/30
# 626/626 - 2s - loss: 0.4747 - accuracy: 0.7255 - val_loss: 0.6687 - val_accuracy: 0.5363 - 2s/epoch - 3ms/step
# Epoch 16/30
# 626/626 - 2s - loss: 0.4672 - accuracy: 0.7225 - val_loss: 0.6618 - val_accuracy: 0.5941 - 2s/epoch - 3ms/step
# Epoch 17/30
# 626/626 - 2s - loss: 0.4572 - accuracy: 0.7260 - val_loss: 0.6634 - val_accuracy: 0.5947 - 2s/epoch - 4ms/step
# Epoch 18/30
# 626/626 - 3s - loss: 0.4506 - accuracy: 0.7328 - val_loss: 0.7517 - val_accuracy: 0.5932 - 3s/epoch - 5ms/step
# Epoch 19/30
# 626/626 - 2s - loss: 0.4479 - accuracy: 0.7296 - val_loss: 0.6769 - val_accuracy: 0.5369 - 2s/epoch - 4ms/step
# Epoch 20/30
# 626/626 - 2s - loss: 0.4421 - accuracy: 0.7280 - val_loss: 0.6865 - val_accuracy: 0.4800 - 2s/epoch - 3ms/step
# Epoch 21/30
# 626/626 - 2s - loss: 0.4403 - accuracy: 0.7271 - val_loss: 0.6798 - val_accuracy: 0.5357 - 2s/epoch - 3ms/step
# Epoch 22/30
# 626/626 - 2s - loss: 0.4382 - accuracy: 0.7255 - val_loss: 0.6670 - val_accuracy: 0.5944 - 2s/epoch - 3ms/step
# Epoch 23/30
# 626/626 - 2s - loss: 0.4382 - accuracy: 0.7245 - val_loss: 0.6696 - val_accuracy: 0.5943 - 2s/epoch - 3ms/step
# Epoch 24/30
# 626/626 - 2s - loss: 0.4403 - accuracy: 0.7195 - val_loss: 0.6747 - val_accuracy: 0.5375 - 2s/epoch - 4ms/step
# Epoch 25/30
# 626/626 - 3s - loss: 0.4326 - accuracy: 0.7271 - val_loss: 0.6756 - val_accuracy: 0.5938 - 3s/epoch - 5ms/step
# Epoch 26/30
# 626/626 - 2s - loss: 0.4313 - accuracy: 0.7286 - val_loss: 0.6750 - val_accuracy: 0.5387 - 2s/epoch - 3ms/step
# Epoch 27/30
# 626/626 - 2s - loss: 0.4342 - accuracy: 0.7258 - val_loss: 0.7869 - val_accuracy: 0.4713 - 2s/epoch - 3ms/step
# Epoch 28/30
# 626/626 - 2s - loss: 0.4341 - accuracy: 0.7236 - val_loss: 0.6716 - val_accuracy: 0.5947 - 2s/epoch - 3ms/step
# Epoch 29/30
# 626/626 - 2s - loss: 0.4302 - accuracy: 0.7259 - val_loss: 0.7009 - val_accuracy: 0.5926 - 2s/epoch - 3ms/step
# Epoch 30/30
# 626/626 - 2s - loss: 0.4301 - accuracy: 0.7248 - val_loss: 0.8159 - val_accuracy: 0.5928 - 2s/epoch - 3ms/step

# %%
sen=["Coworkers at bathroom sink locked in tense standoff over who is going to wash hands longer",
    "The covid cases are rising"]
seq=tokenizer.texts_to_sequences(sen)
padded=pad_sequences(seq,maxlen=max_length,padding=padding_type,truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 110ms/step
# [[0.98818344]
#  [0.05000471]]
